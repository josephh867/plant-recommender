# %% [markdown]
# # Plant Recommender Project
#
# ## Data Loading and Cleaning

# %% [markdown]
# For this prject, I will be interfacing with a `SQLite` database pulled from the [USDA PLANTS Database](https://plants.sc.egov.usda.gov/home). This data was collected via the use of an API that the USDA provides for all of their databases. To read in the SQL data correctly:

# %%
# Imports
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# I used [this](https://datacarpentry.org/python-ecology-lesson/09-working-with-sql/index.html) site to help me import data.

# %%
# Read in the data into a dataframe
con = sqlite3.connect('../datasets/usdadb_new.sqlite3')
df = pd.read_sql_query('''
                       SELECT * 
                       FROM usda
                       WHERE Temperature_Minimum_F IS NOT ''
                       ''', con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

# Close the connection
con.close()
# Out:
#    id Symbol Accepted_Symbol_x Synonym_Symbol_x  \
# 0  21   ABBA              ABBA
# 1  40   ABCO              ABCO
# 2  55   ABFR              ABFR
# 3  62   ABGR              ABGR
# 4  65  ABGR4             ABGR4
#
#                                    Scientific_Name_x Hybrid_Genus_Indicator  \
# 0                          Abies balsamea (L.) Mill.
# 1  Abies concolor (Gord. & Glend.) Lindl. ex Hild...
# 2                        Abies fraseri (Pursh) Poir.
# 3           Abies grandis (Douglas ex D. Don) Lindl.
# 4      Abelia ×grandiflora (Rovelli ex André) Rehder
#
#   Hybrid_Species_Indicator      Species Subspecies_Prefix  \
# 0                              balsamea
# 1                              concolor
# 2                               fraseri
# 3                               grandis
# 4                        ×  grandiflora
#
#   Hybrid_Subspecies_Indicator  ... Naval_Store_Product Nursery_Stock_Product  \
# 0                              ...                 Yes                   Yes
# 1                              ...                  No                   Yes
# 2                              ...                  No                   Yes
# 3                              ...                  No                   Yes
# 4                              ...                  No                   Yes
#
#   Palatable_Browse_Animal Palatable_Graze_Animal Palatable_Human Post_Product  \
# 0                  Medium                                     No           No
# 1                     Low                                     No           No
# 2                     Low                                     No           No
# 3                     Low                                     No           No
# 4                     Low                                     No           No
#
#   Protein_Potential Pulpwood_Product Veneer_Product   Genus
# 0               Low              Yes            Yes   Abies
# 1               Low              Yes            Yes   Abies
# 2               Low              Yes            Yes   Abies
# 3               Low              Yes            Yes   Abies
# 4               Low               No             No  Abelia
#
# [5 rows x 134 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Columns: 134 entries, id to Genus
# dtypes: int64(1), object(133)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['id', 'Symbol', 'Accepted_Symbol_x', 'Synonym_Symbol_x',
#        'Scientific_Name_x', 'Hybrid_Genus_Indicator',
#        'Hybrid_Species_Indicator', 'Species', 'Subspecies_Prefix',
#        'Hybrid_Subspecies_Indicator',
#        ...
#        'Naval_Store_Product', 'Nursery_Stock_Product',
#        'Palatable_Browse_Animal', 'Palatable_Graze_Animal', 'Palatable_Human',
#        'Post_Product', 'Protein_Potential', 'Pulpwood_Product',
#        'Veneer_Product', 'Genus'],
#       dtype='object', length=134)

# %%
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# There do not seem to be any nulls in the dataset. The main challenge here will be converting the columns to useable data for clustering. The first step here will be to cut down the number of features to only include features relevant to growing conditions:

# %%
df.head(40)
# Out:
#       id  Symbol Accepted_Symbol_x Synonym_Symbol_x  \
# 0     21    ABBA              ABBA
# 1     40    ABCO              ABCO
# 2     55    ABFR              ABFR
# 3     62    ABGR              ABGR
# 4     65   ABGR4             ABGR4
# 5     85    ABLA              ABLA
# 6     93    ABMA              ABMA
# 7    137    ABPR              ABPR
# 8    358   ACCA4             ACCA4
# 9    399   ACCO2             ACCO2
# 10   407   ACCO4             ACCO4
# 11   433   ACCY2             ACCY2
# 12   546  ACGLD4            ACGLD4
# 13   557    ACGR              ACGR
# 14   618    ACHY              ACHY
# 15   689   ACLE9             ACLE9
# 16   691   ACLEL             ACLEL
# 17   702    ACLO              ACLO
# 18   729    ACME              ACME
# 19   740   ACMI2             ACMI2
# 20   764   ACMIO             ACMIO
# 21   797   ACNE2             ACNE2
# 22   808   ACNED             ACNED
# 23   860   ACOCO             ACOCO
# 24   945    ACPS              ACPS
# 25  1009    ACRU              ACRU
# 26  1033   ACSA2             ACSA2
# 27  1102  ACSP12            ACSP12
# 28  1103   ACSP2             ACSP2
# 29  1165   ACTH7             ACTH7
# 30  1206    ACVI              ACVI
# 31  1288    ADFA              ADFA
# 32  1468    AEPA              AEPA
# 33  1595   AGAU2             AGAU2
# 34  1640   AGCA4             AGCA4
# 35  1641   AGCA5             AGCA5
# 36  1701   AGDE2             AGDE2
# 37  1733    AGEX              AGEX
# 38  1752    AGFR              AGFR
# 39  1762   AGGI2             AGGI2
#
#                                     Scientific_Name_x Hybrid_Genus_Indicator  \
# 0                           Abies balsamea (L.) Mill.
# 1   Abies concolor (Gord. & Glend.) Lindl. ex Hild...
# 2                         Abies fraseri (Pursh) Poir.
# 3            Abies grandis (Douglas ex D. Don) Lindl.
# 4       Abelia ×grandiflora (Rovelli ex André) Rehder
# 5                      Abies lasiocarpa (Hook.) Nutt.
# 6                       Abies magnifica A. Murray bis
# 7                                Abies procera Rehder
# 8                                   Acorus calamus L.
# 9                            Acacia constricta Benth.
# 10                         Aconitum columbianum Nutt.
# 11                  Acacia cyclops A. Cunn. ex G. Don
# 12   Acer glabrum Torr. var. douglasii (Hook.) Dippel
# 13                             Acacia greggii A. Gray
# 14  Achnatherum hymenoides (Roem. & Schult.) Barkw...
# 15          Achnatherum lettermanii (Vasey) Barkworth
# 16  Achnatherum lemmonii (Vasey) Barkworth var. le...
# 17                 Acacia longifolia (Andrews) Willd.
# 18                          Acacia melanoxylon R. Br.
# 19                            Achillea millefolium L.
# 20      Achillea millefolium L. var. occidentalis DC.
# 21                                    Acer negundo L.
# 22  Achnatherum nelsonii (Scribn.) Barkworth ssp. ...
# 23  Achnatherum occidentale (Thurb.) Barkworth ssp...
# 24                             Acer pseudoplatanus L.
# 25                                     Acer rubrum L.
# 26                                Acer saccharinum L.
# 27    Achnatherum speciosum (Trin. & Rupr.) Barkworth
# 28                                 Acer spicatum Lam.
# 29         Achnatherum thurberianum (Piper) Barkworth
# 30                              Acalypha virginica L.
# 31               Adenostoma fasciculatum Hook. & Arn.
# 32                                  Aesculus pavia L.
# 33                 Agoseris aurantiaca (Hook.) Greene
# 34                                 Agrostis canina L.
# 35                             Agrostis capillaris L.
# 36      Agropyron desertorum (Fisch. ex Link) Schult.
# 37                             Agrostis exarata Trin.
# 38               Agropyron fragile (Roth) P. Candargy
# 39                             Agrostis gigantea Roth
#
#    Hybrid_Species_Indicator         Species Subspecies_Prefix  \
# 0                                  balsamea
# 1                                  concolor
# 2                                   fraseri
# 3                                   grandis
# 4                         ×     grandiflora
# 5                                lasiocarpa
# 6                                 magnifica
# 7                                   procera
# 8                                   calamus
# 9                                constricta
# 10                              columbianum
# 11                                  cyclops
# 12                                  glabrum
# 13                                  greggii
# 14                               hymenoides
# 15                              lettermanii
# 16                                 lemmonii
# 17                               longifolia
# 18                              melanoxylon
# 19                              millefolium
# 20                              millefolium
# 21                                  negundo
# 22                                 nelsonii              ssp.
# 23                              occidentale              ssp.
# 24                           pseudoplatanus
# 25                                   rubrum
# 26                              saccharinum
# 27                                speciosum
# 28                                 spicatum
# 29                             thurberianum
# 30                                virginica
# 31                             fasciculatum
# 32                                    pavia
# 33                               aurantiaca
# 34                                   canina
# 35                               capillaris
# 36                               desertorum
# 37                                  exarata
# 38                                  fragile
# 39                                 gigantea
#
#    Hybrid_Subspecies_Indicator  ... Naval_Store_Product Nursery_Stock_Product  \
# 0                               ...                 Yes                   Yes
# 1                               ...                  No                   Yes
# 2                               ...                  No                   Yes
# 3                               ...                  No                   Yes
# 4                               ...                  No                   Yes
# 5                               ...                  No                   Yes
# 6                               ...                  No                   Yes
# 7                               ...                  No                   Yes
# 8                               ...                  No                   Yes
# 9                               ...                  No                    No
# 10                              ...                  No                   Yes
# 11                              ...                  No                   Yes
# 12                              ...                  No                   Yes
# 13                              ...                  No                    No
# 14                              ...                  No                    No
# 15                              ...                  No                    No
# 16                              ...                  No                    No
# 17                              ...                  No                   Yes
# 18                              ...                  No                   Yes
# 19                              ...                  No                   Yes
# 20                              ...                  No                    No
# 21                              ...                  No                   Yes
# 22                              ...                  No                    No
# 23                              ...                  No                    No
# 24                              ...                  No                   Yes
# 25                              ...                  No                   Yes
# 26                              ...                  No                   Yes
# 27                              ...                  No                    No
# 28                              ...                  No                   Yes
# 29                              ...                  No                    No
# 30                              ...                  No                   Yes
# 31                              ...                  No                    No
# 32                              ...                  No                   Yes
# 33                              ...                  No                    No
# 34                              ...                  No                   Yes
# 35                              ...                  No                    No
# 36                              ...                  No                    No
# 37                              ...                  No                    No
# 38                              ...                  No                    No
# 39                              ...                  No                    No
#
#    Palatable_Browse_Animal Palatable_Graze_Animal Palatable_Human  \
# 0                   Medium                                     No
# 1                      Low                                     No
# 2                      Low                                     No
# 3                      Low                                     No
# 4                      Low                                     No
# 5                      Low                                     No
# 6                      Low                    Low              No
# 7                      Low                    Low              No
# 8                      Low                    Low              No
# 9                      Low                                    Yes
# 10                     Low                    Low              No
# 11                     Low                                     No
# 12                  Medium                 Medium              No
# 13                  Medium                                    Yes
# 14                    High                   High              No
# 15                    High                   High              No
# 16                  Medium                 Medium              No
# 17                     Low                                     No
# 18                     Low                                     No
# 19                  Medium                    Low              No
# 20                     Low                    Low              No
# 21                     Low                    Low             Yes
# 22                     Low                 Medium              No
# 23                  Medium                 Medium              No
# 24                     Low                    Low              No
# 25                  Medium                    Low             Yes
# 26                     Low                    Low             Yes
# 27                  Medium                 Medium              No
# 28                  Medium                    Low              No
# 29                     Low                 Medium              No
# 30                     Low                    Low              No
# 31                  Medium                    Low              No
# 32                     Low                    Low              No
# 33                  Medium                 Medium              No
# 34                     Low                 Medium              No
# 35                     Low                 Medium              No
# 36                     Low                   High              No
# 37                  Medium                   High              No
# 38                  Medium                 Medium              No
# 39                    High                   High              No
#
#    Post_Product Protein_Potential Pulpwood_Product Veneer_Product        Genus
# 0            No               Low              Yes            Yes        Abies
# 1            No               Low              Yes            Yes        Abies
# 2            No               Low              Yes            Yes        Abies
# 3            No               Low              Yes            Yes        Abies
# 4            No               Low               No             No       Abelia
# 5            No               Low              Yes             No        Abies
# 6            No               Low              Yes            Yes        Abies
# 7            No               Low              Yes            Yes        Abies
# 8            No               Low               No             No       Acorus
# 9            No            Medium               No             No       Acacia
# 10           No               Low               No             No     Aconitum
# 11           No               Low               No             No       Acacia
# 12           No               Low               No             No         Acer
# 13           No            Medium               No             No       Acacia
# 14           No            Medium               No             No  Achnatherum
# 15           No               Low               No             No  Achnatherum
# 16           No               Low               No             No  Achnatherum
# 17           No               Low               No             No       Acacia
# 18           No               Low               No             No       Acacia
# 19           No               Low               No             No     Achillea
# 20           No               Low               No             No     Achillea
# 21           No               Low              Yes             No         Acer
# 22           No            Medium               No             No  Achnatherum
# 23           No               Low               No             No  Achnatherum
# 24           No               Low               No             No         Acer
# 25           No               Low              Yes            Yes         Acer
# 26           No               Low               No            Yes         Acer
# 27           No               Low               No             No  Achnatherum
# 28           No               Low               No             No         Acer
# 29           No               Low               No             No  Achnatherum
# 30           No               Low               No             No     Acalypha
# 31           No            Medium               No             No   Adenostoma
# 32           No               Low               No             No     Aesculus
# 33           No            Medium               No             No     Agoseris
# 34           No            Medium               No             No     Agrostis
# 35           No            Medium               No             No     Agrostis
# 36           No            Medium               No             No    Agropyron
# 37           No            Medium               No             No     Agrostis
# 38           No            Medium               No             No    Agropyron
# 39           No            Medium               No             No     Agrostis
#
# [40 rows x 134 columns]

# %%
df.tail(40)
# Out:
#          id  Symbol Accepted_Symbol_x Synonym_Symbol_x  \
# 1039  87983   TRMA3             TRMA3
# 1040  88428   TRSP2             TRSP2
# 1041  88605    TRWO              TRWO
# 1042  88625    TSHE              TSHE
# 1043  88627    TSME              TSME
# 1044  88717    TYAN              TYAN
# 1045  88729    TYLA              TYLA
# 1046  88816    UMCA              UMCA
# 1047  88866    UNPA              UNPA
# 1048  88885   URBR2             URBR2
# 1049  88957   URMA3             URMA3
# 1050  88960    URMU              URMU
# 1051  88984    URRA              URRA
# 1052  89208    VAAN              VAAN
# 1053  89244  VACA13              VACE           VACA13
# 1054  89273    VACO              VACO
# 1055  89388    VAOV              VAOV
# 1056  89389   VAOV2             VAOV2
# 1057  89398    VAPA              VAPA
# 1058  89430    VASC              VASC
# 1059  89658    VEEN              VEEN
# 1060  90029    VIAC              VIAC
# 1061  90247    VICR              VICR
# 1062  90279   VIDEL             VIRE7            VIDEL
# 1063  90414    VILA              VILA
# 1064  90416  VILA11            VILA11
# 1065  90439    VILE              VILE
# 1066  90504   VIMI2             VIMI2
# 1067  90563   VINUC             VINUC
# 1068  90591    VIOP              VIOP
# 1069  90592  VIOPA2            VIOPA2
# 1070  90668    VIPR              VIPR
# 1071  90727    VIRA              VIRA
# 1072  91347    WYMO              WYMO
# 1073  91563    XETE              XETE
# 1074  91741    YUBA              YUBA
# 1075  91752   YUBRB             YUBRB
# 1076  91764    YUEL              YUEL
# 1077  91776    YUGL              YUGL
# 1078  92008    ZIAQ              ZIAQ
#
#                                       Scientific_Name_x  \
# 1039              Trifolium macrocephalum (Pursh) Poir.
# 1040                   Trisetum spicatum (L.) K. Richt.
# 1041                       Trifolium wormskioldii Lehm.
# 1042                    Tsuga heterophylla (Raf.) Sarg.
# 1043                 Tsuga mertensiana (Bong.) Carrière
# 1044                              Typha angustifolia L.
# 1045                                 Typha latifolia L.
# 1046      Umbellularia californica (Hook. & Arn.) Nutt.
# 1047                               Uniola paniculata L.
# 1048  Urochloa brizantha (Hochst. ex A. Rich.) R. We...
# 1049                 Urochloa maxima (Jacq.) R. Webster
# 1050              Urochloa mutica (Forssk.) T.Q. Nguyen
# 1051                        Urochloa ramosa (L.) Nguyen
# 1052                      Vaccinium angustifolium Aiton
# 1053           Vaccinium caespitosum Michx., orth. var.
# 1054                            Vaccinium corymbosum L.
# 1055                          Vaccinium ovalifolium Sm.
# 1056                             Vaccinium ovatum Pursh
# 1057                          Vaccinium parvifolium Sm.
# 1058             Vaccinium scoparium Leiberg ex Coville
# 1059  Verbesina encelioides (Cav.) Benth. & Hook. f....
# 1060                            Viburnum acerifolium L.
# 1061                                    Vicia cracca L.
# 1062            Viburnum dentatum L. var. lucidum Aiton
# 1063                                Viburnum lantana L.
# 1064                        Viburnum lantanoides Michx.
# 1065                                Viburnum lentago L.
# 1066                                     Vinca minor L.
# 1067  Viburnum nudum L. var. cassinoides (L.) Torr. ...
# 1068                                 Viburnum opulus L.
# 1069           Viburnum opulus L. var. americanum Aiton
# 1070                            Viburnum prunifolium L.
# 1071                    Viburnum rafinesqueanum Schult.
# 1072                             Wyethia mollis A. Gray
# 1073                    Xerophyllum tenax (Pursh) Nutt.
# 1074                                Yucca baccata Torr.
# 1075           Yucca brevifolia Engelm. var. brevifolia
# 1076                      Yucca elata (Engelm.) Engelm.
# 1077                                 Yucca glauca Nutt.
# 1078                                Zizania aquatica L.
#
#      Hybrid_Genus_Indicator Hybrid_Species_Indicator         Species  \
# 1039                                                   macrocephalum
# 1040                                                        spicatum
# 1041                                                    wormskioldii
# 1042                                                    heterophylla
# 1043                                                     mertensiana
# 1044                                                    angustifolia
# 1045                                                       latifolia
# 1046                                                     californica
# 1047                                                      paniculata
# 1048                                                       brizantha
# 1049                                                          maxima
# 1050                                                          mutica
# 1051                                                          ramosa
# 1052                                                   angustifolium
# 1053                                                     caespitosum
# 1054                                                      corymbosum
# 1055                                                     ovalifolium
# 1056                                                          ovatum
# 1057                                                     parvifolium
# 1058                                                       scoparium
# 1059                                                     encelioides
# 1060                                                     acerifolium
# 1061                                                          cracca
# 1062                                                        dentatum
# 1063                                                         lantana
# 1064                                                     lantanoides
# 1065                                                         lentago
# 1066                                                           minor
# 1067                                                           nudum
# 1068                                                          opulus
# 1069                                                          opulus
# 1070                                                     prunifolium
# 1071                                                  rafinesqueanum
# 1072                                                          mollis
# 1073                                                           tenax
# 1074                                                         baccata
# 1075                                                      brevifolia
# 1076                                                           elata
# 1077                                                          glauca
# 1078                                                        aquatica
#
#      Subspecies_Prefix Hybrid_Subspecies_Indicator  ... Naval_Store_Product  \
# 1039                                                ...                  No
# 1040                                                ...                  No
# 1041                                                ...                  No
# 1042                                                ...                  No
# 1043                                                ...                  No
# 1044                                                ...                  No
# 1045                                                ...                  No
# 1046                                                ...                 Yes
# 1047                                                ...                  No
# 1048                                                ...                  No
# 1049                                                ...                  No
# 1050                                                ...                  No
# 1051                                                ...                  No
# 1052                                                ...                  No
# 1053                                                ...                  No
# 1054                                                ...                  No
# 1055                                                ...                  No
# 1056                                                ...                  No
# 1057                                                ...                  No
# 1058                                                ...                  No
# 1059                                                ...                  No
# 1060                                                ...                  No
# 1061                                                ...                  No
# 1062                                                ...                  No
# 1063                                                ...                  No
# 1064                                                ...                  No
# 1065                                                ...                  No
# 1066                                                ...                  No
# 1067                                                ...                  No
# 1068                                                ...                  No
# 1069                                                ...                  No
# 1070                                                ...                  No
# 1071                                                ...                  No
# 1072                                                ...                  No
# 1073                                                ...                  No
# 1074                                                ...                  No
# 1075                                                ...                  No
# 1076                                                ...                  No
# 1077                                                ...                  No
# 1078                                                ...                  No
#
#      Nursery_Stock_Product Palatable_Browse_Animal Palatable_Graze_Animal  \
# 1039                    No                  Medium                   High
# 1040                    No                    High                   High
# 1041                    No                  Medium                   High
# 1042                   Yes                     Low                    Low
# 1043                   Yes                  Medium                    Low
# 1044                    No                     Low                    Low
# 1045                    No                     Low                    Low
# 1046                   Yes                  Medium                    Low
# 1047                   Yes                    High                 Medium
# 1048                    No                  Medium                 Medium
# 1049                    No                    High                 Medium
# 1050                    No                  Medium                   High
# 1051                    No                  Medium                    Low
# 1052                    No                    High                 Medium
# 1053                   Yes                     Low                    Low
# 1054                   Yes                  Medium                    Low
# 1055                    No                    High                    Low
# 1056                   Yes                  Medium                   High
# 1057                   Yes                  Medium                    Low
# 1058                   Yes                     Low                    Low
# 1059                    No                     Low                    Low
# 1060                    No                  Medium                    Low
# 1061                    No                    High                   High
# 1062                   Yes                     Low                    Low
# 1063                   Yes                     Low                    Low
# 1064                    No                    High                    Low
# 1065                   Yes                     Low                    Low
# 1066                   Yes                     Low                    Low
# 1067                    No                    High                    Low
# 1068                   Yes                     Low                    Low
# 1069                   Yes                     Low                    Low
# 1070                    No                  Medium                    Low
# 1071                    No                     Low                    Low
# 1072                    No                     Low                    Low
# 1073                    No                     Low                    Low
# 1074                   Yes                     Low                    Low
# 1075                   Yes                     Low                    Low
# 1076                   Yes                     Low                    Low
# 1077                   Yes                     Low                    Low
# 1078                    No                    High                 Medium
#
#      Palatable_Human Post_Product Protein_Potential Pulpwood_Product  \
# 1039              No           No            Medium               No
# 1040              No           No            Medium               No
# 1041              No           No            Medium               No
# 1042              No           No               Low              Yes
# 1043              No           No               Low              Yes
# 1044             Yes           No               Low               No
# 1045              No           No               Low               No
# 1046             Yes           No               Low               No
# 1047              No           No               Low               No
# 1048              No           No            Medium               No
# 1049              No           No            Medium               No
# 1050              No           No            Medium               No
# 1051              No           No               Low               No
# 1052             Yes           No               Low               No
# 1053             Yes           No               Low               No
# 1054             Yes           No               Low               No
# 1055             Yes           No               Low               No
# 1056             Yes           No               Low               No
# 1057             Yes           No               Low               No
# 1058             Yes           No               Low               No
# 1059              No           No               Low               No
# 1060              No           No               Low               No
# 1061              No           No            Medium               No
# 1062              No           No               Low               No
# 1063              No           No               Low               No
# 1064              No           No               Low               No
# 1065              No           No               Low               No
# 1066              No           No               Low               No
# 1067              No           No               Low               No
# 1068              No           No               Low               No
# 1069              No           No               Low               No
# 1070              No           No               Low               No
# 1071              No           No               Low               No
# 1072             Yes           No               Low               No
# 1073              No           No               Low               No
# 1074              No           No               Low               No
# 1075              No           No               Low               No
# 1076              No           No               Low               No
# 1077              No           No               Low               No
# 1078             Yes           No            Medium               No
#
#      Veneer_Product         Genus
# 1039             No     Trifolium
# 1040             No      Trisetum
# 1041             No     Trifolium
# 1042            Yes         Tsuga
# 1043            Yes         Tsuga
# 1044             No         Typha
# 1045             No         Typha
# 1046            Yes  Umbellularia
# 1047             No        Uniola
# 1048             No      Urochloa
# 1049             No      Urochloa
# 1050             No      Urochloa
# 1051             No      Urochloa
# 1052             No     Vaccinium
# 1053             No     Vaccinium
# 1054             No     Vaccinium
# 1055             No     Vaccinium
# 1056             No     Vaccinium
# 1057             No     Vaccinium
# 1058             No     Vaccinium
# 1059             No     Verbesina
# 1060             No      Viburnum
# 1061             No         Vicia
# 1062             No      Viburnum
# 1063             No      Viburnum
# 1064             No      Viburnum
# 1065             No      Viburnum
# 1066             No         Vinca
# 1067             No      Viburnum
# 1068             No      Viburnum
# 1069             No      Viburnum
# 1070             No      Viburnum
# 1071             No      Viburnum
# 1072             No       Wyethia
# 1073             No   Xerophyllum
# 1074             No         Yucca
# 1075             No         Yucca
# 1076             No         Yucca
# 1077             No         Yucca
# 1078             No       Zizania
#
# [40 rows x 134 columns]

# %%
df.to_csv('../datasets/raw-filtered-data.csv', index=False)

# %% [markdown]
# The only way I know how to filter this data down in terms of features available is to create a list of features to keep. Here is the list of features I will keep in this dataset for later use - note that I will be keeping `id` just so I can cross-reference it with the initial dataset and `SQLite` database:

# %%
features = ['id', 'Scientific_Name_x', 'Category', 'Family', 'Growth_Habit', 'Native_Status',
           'Active_Growth_Period', 'Fall_Conspicuous', 'Fire_Resistance', 'Flower_Color',
           'Flower_Conspicuous', 'Fruit_Conspicuous', 'Growth_Rate', 'Lifespan', 'Toxicity',
           'Drought_Tolerance', 'Hedge_Tolerance', 'Moisture_Use', 'pH_Minimum', 'pH_Maximum',
           'Salinity_Tolerance', 'Shade_Tolerance', 'Temperature_Minimum_F', 'Bloom_Period']

# %%
df = df[features]

# %% [markdown]
# Now let's begin the process of one-hot encoding all of the categorical features and scaling all of the ordinal features. Most of the features listed above fall into either one of these categories. I will first separate these features by categorical, ordinal, or nominal:

# %%
categorical_features = ['Category', 'Family', 'Growth_Habit', 'Native_Status',
           'Active_Growth_Period', 'Fall_Conspicuous', 'Flower_Color',
           'Flower_Conspicuous', 'Fruit_Conspicuous', 'Bloom_Period', 'Fire_Resistance']

ordinal_features = ['Toxicity', 'Drought_Tolerance', 'Hedge_Tolerance',
                   'Moisture_Use', 'Salinity_Tolerance', 'Shade_Tolerance', 'Growth_Rate', 'Lifespan']

other_features = ['id', 'Scientific_Name_x', 'pH_Minimum', 'pH_Maximum',
                      'Temperature_Minimum_F']

# %% [markdown]
# I pulled the following function from [this Kaggle submission.](https://www.kaggle.com/taolearnstolearn/a-single-pipeline-with-lasso-regression) This will allow me to create a dictionary of numeric values to map to the unique strings contained in each feature.

# %%
# Print out unique keys for each categorical feature
for feature in categorical_features:
    print(feature, df[feature].unique())
# Out:
# Category ['Gymnosperm' 'Dicot' 'Monocot' '' 'Fern' 'Horsetail']
# Family ['Pinaceae' 'Caprifoliaceae' 'Acoraceae' 'Fabaceae' 'Ranunculaceae'
#  'Aceraceae' 'Poaceae' 'Asteraceae' 'Euphorbiaceae' 'Rosaceae'
#  'Hippocastanaceae' 'Lamiaceae' 'Agavaceae' 'Simaroubaceae' 'Liliaceae' ''
#  'Alismataceae' 'Betulaceae' 'Vitaceae' 'Boraginaceae' 'Acanthaceae'
#  'Ericaceae' 'Brassicaceae' 'Plumbaginaceae' 'Araliaceae' 'Papaveraceae'
#  'Araceae' 'Asclepiadaceae' 'Annonaceae' 'Chenopodiaceae' 'Verbenaceae'
#  'Bromeliaceae' 'Cyperaceae' 'Campanulaceae' 'Cabombaceae' 'Juglandaceae'
#  'Fagaceae' 'Scrophulariaceae' 'Clusiaceae' 'Bignoniaceae' 'Berberidaceae'
#  'Rhamnaceae' 'Ulmaceae' 'Celastraceae' 'Dicksoniaceae' 'Clethraceae'
#  'Portulacaceae' 'Cornaceae' 'Fumariaceae' 'Myricaceae' 'Cucurbitaceae'
#  'Primulaceae' 'Elaeagnaceae' 'Onagraceae' 'Ephedraceae' 'Equisetaceae'
#  'Hydrophyllaceae' 'Polygonaceae' 'Hydrangeaceae' 'Cactaceae'
#  'Fouquieriaceae' 'Oleaceae' 'Sterculiaceae' 'Rubiaceae' 'Garryaceae'
#  'Gentianaceae' 'Geraniaceae' 'Hamamelidaceae' 'Saxifragaceae' 'Apiaceae'
#  'Malvaceae' 'Cistaceae' 'Aquifoliaceae' 'Polemoniaceae' 'Iridaceae'
#  'Juncaceae' 'Cupressaceae' 'Krameriaceae' 'Lythraceae' 'Zygophyllaceae'
#  'Lemnaceae' 'Lauraceae' 'Linaceae' 'Solanaceae' 'Moraceae' 'Magnoliaceae'
#  'Nymphaeaceae' 'Buxaceae' 'Phytolaccaceae' 'Plantaginaceae' 'Salicaceae'
#  'Punicaceae' 'Anacardiaceae' 'Grossulariaceae' 'Ruppiaceae' 'Sapindaceae'
#  'Simmondsiaceae' 'Sapotaceae' 'Smilacaceae' 'Orchidaceae'
#  'Caryophyllaceae' 'Taxaceae' 'Rutaceae' 'Tiliaceae' 'Typhaceae'
#  'Apocynaceae']
# Growth_Habit ['Tree' 'Shrub' 'Forb/herb' 'Tree, Shrub' 'Graminoid'
#  'Subshrub, Forb/herb' 'Forb/herb, Shrub, Subshrub'
#  'Subshrub, Shrub, Forb/herb' '' 'Subshrub, Shrub' 'Vine'
#  'Vine, Forb/herb' 'Subshrub, Shrub, Graminoid' 'Subshrub'
#  'Tree, Shrub, Vine' 'Shrub, Subshrub' 'Forb/herb, Subshrub' 'Shrub, Tree'
#  'Tree, Subshrub, Shrub' 'Vine, Subshrub' 'Shrub, Vine']
# Native_Status ['L48 (N), CAN (N), SPM (N)' 'L48 (N)' 'L48 (N), CAN (N)' 'L48 (I)'
#  'L48 (N), AK (N), CAN (N)' 'L48 (I), CAN (I)' 'L48 (N), AK (I?), CAN (N)'
#  'L48 (I), HI (I)' 'L48 (NI), AK (N), HI (I), CAN (NI), GL (N), SPM (NI)'
#  'L48 (N), AK (N), CAN (N), GL (N), SPM (N)' 'L48 (N), CAN (I)'
#  'L48 (N), HI (I), CAN (W), GL (I), SPM (W)'
#  'L48 (I), AK (I), HI (I), CAN (I), GL (I), SPM (I)'
#  'L48 (I), AK (I), CAN (I), GL (I)' 'L48 (N), PR (N), CAN (N)'
#  'L48 (I), HI (I), CAN (I)' 'L48 (N), AK (N), CAN (N), GL (N)' ''
#  'L48 (I), CAN (W)' 'L48 (N), AK (N), CAN (N), SPM (N)' 'L48 (I), AK (I)'
#  'L48 (I), AK (I), CAN (I), GL (I), SPM (I)' 'L48 (N), AK (I), CAN (N)'
#  'L48 (N), HI (I), PR (N), VI (I)' 'L48 (N), PR (N), VI (N)'
#  'L48 (N), HI (I), PR (N), CAN (N)' 'L48 (I), HI (I), PR (I), VI (I)'
#  'L48 (I), AK (I), HI (I), CAN (I)' 'AK (N), CAN (N), GL (N)'
#  'L48 (N), HI (I)'
#  'L48 (I), AK (I), HI (I), PR (I), CAN (W), GL (W), SPM (W)'
#  'L48 (N), AK (I), CAN (I)' 'L48 (N), HI (I), CAN (N)' 'PR (N)'
#  'L48 (I), AK (I), CAN (I)' 'L48 (NI), AK (NI), CAN (NI), GL (I), SPM (I)'
#  'L48 (I), AK (I), HI (I), PR (I), VI (I), CAN (I)'
#  'L48 (I), PR (N), VI (I)' 'L48 (N), AK (N), HI (N), CAN (N), SPM (N)'
#  'L48 (I), PR (I)' 'HI (I), PR (I)' 'L48 (N), CAN (N), GL (N), SPM (N)'
#  'L48 (N), AK (N), CAN (NI), GL (N), SPM (NI)' 'L48 (I), HI (I), VI (I)'
#  'L48 (N), AK (I), CAN (N), SPM (W)' 'HI (N)' 'L48 (I), CAN (I), SPM (I)'
#  'L48 (I), HI (I), PR (I)'
#  'L48 (I), HI (I), PR (I), VI (I), CAN (W), SPM (W)'
#  'L48 (I), AK (I), HI (I), PR (I), CAN (I), GL (I), SPM (I)'
#  'AK (I), CAN (N)' 'L48 (N), AK (I), HI (I), CAN (I)'
#  'L48 (NI), AK (NI), HI (I), CAN (NI), GL (NI), SPM (N)'
#  'L48 (N), AK (I), HI (I), PR (I), CAN (I), SPM (I)'
#  'L48 (N), HI (N), PR (N), VI (N)'
#  'L48 (N), HI (N), PR (N), VI (N), CAN (N)' 'CAN (I)'
#  'L48 (N), AK (N), HI (I), CAN (N)'
#  'L48 (I), AK (I), HI (I), CAN (W), GL (W)'
#  'L48 (N), AK (N), HI (I), CAN (N), SPM (N)' 'L48 (N), PR (N)'
#  'L48 (N), AK (N), HI (I), PR (N), CAN (N), SPM (N)'
#  'L48 (I), HI (I), PR (I), VI (I), CAN (I)' 'L48 (I), CAN (I), GL (I)'
#  'L48 (I), AK (I), HI (I), CAN (I), SPM (I)' 'L48 (I), PR (I), CAN (I)'
#  'L48 (I), HI (I), PR (I), CAN (I)' 'L48 (N), HI (I), PR (N)'
#  'L48 (N), HI (I), PR (N), VI (N)' 'L48 (N), AK (I), CAN (N), SPM (I)'
#  'L48 (N), CAN (NI)'
#  'L48 (I), AK (I), HI (I), PR (I), VI (I), CAN (I), GL (I), SPM (I)'
#  'L48 (N), CAN (N), GL (N)' 'L48 (N), AK (N), CAN (N), GL (I), SPM (N)'
#  'L48 (NI), AK (NI), HI (I), PR (I), CAN (NI), GL (N), SPM (I)'
#  'L48 (N), HI (I), VI (I)' 'L48 (N), AK (I), CAN (N), SPM (N)'
#  'L48 (I), PR (I), VI (I)' 'L48 (I), CAN (N)'
#  'L48 (I), AK (I), CAN (I), SPM (I)'
#  'L48 (N), AK (N), HI (N), PR (N), VI (N), CAN (N), SPM (N)'
#  'L48 (N), HI (I), PR (N), VI (I), CAN (N)' 'AK (N), CAN (N)'
#  'L48 (I), AK (I), CAN (W), GL (W)' 'L48 (I), VI (I), CAN (W)'
#  'L48 (I), HI (I), CAN (I), SPM (W)' 'L48 (N), PR (I)'
#  'L48 (N), PR (I), CAN (N)' 'L48 (N), PR (N), VI (N), CAN (N)'
#  'L48 (N), AK (N?), CAN (N)' 'L48 (NI), CAN (N)' 'PR (I)'
#  'L48 (NI), CAN (NI), SPM (N)']
# Active_Growth_Period ['Spring and Summer' 'Spring, Summer, Fall' 'Spring'
#  'Fall, Winter and Spring' 'Spring and Fall' 'Summer' 'Year Round' ''
#  'Summer and Fall']
# Fall_Conspicuous ['No' 'Yes']
# Flower_Color ['Yellow' 'Red' 'Purple' '' 'Brown' 'Blue' 'Green' 'White' 'Orange']
# Flower_Conspicuous ['No' 'Yes']
# Fruit_Conspicuous ['No' 'Yes']
# Bloom_Period ['Mid Summer' 'Late Spring' 'Mid Spring' 'Late Summer' 'Early Summer'
#  'Summer' 'Early Spring' 'Spring' 'Fall' 'Late Winter' '' 'Winter'
#  'Indeterminate']
# Fire_Resistance ['No' 'Yes']

# %%
# Print out unique keys for each ordinal feature
for feature in ordinal_features:
    print(feature, df[feature].unique())
# Out:
# Toxicity ['None' 'Slight' 'Moderate' 'Severe' '']
# Drought_Tolerance ['Low' 'Medium' 'None' 'High']
# Hedge_Tolerance ['Low' 'High' 'None' 'Medium' '']
# Moisture_Use ['Medium' 'Low' 'High']
# Salinity_Tolerance ['None' 'Low' 'Medium' 'High']
# Shade_Tolerance ['Tolerant' 'Intermediate' 'Intolerant']
# Growth_Rate ['Slow' 'Moderate' 'Rapid' '']
# Lifespan ['Short' 'Long' 'Moderate' '']

# %%
# Dictionary to map the ordinal features
ord_dict = {
   # Toxicity
   'None':0, 'Slight':1, 'Moderate':2, 'Severe':3,
    
   # Tolerances other than shade tolerance
   'None':0, 'Low':1, 'Medium':2, 'High':3,

   # Shade Tolerance
   'Intolerant':0, 'Intermediate':1, 'Tolerant':2,
    
   # Unique keys for Growth Rate and Lifespan
   'Slow':1, 'Short':1, 'Long':3, 'Rapid':3
}

# %%
# Map the ordinal features to numeric values to retain their ordinality
def ordinal_mapper(df, ord_features):
    # Fill empty strings with 0
    df[ord_features] = df[ord_features].replace('', -1)
    
    # Get values from the dictionary using the get method
    df = df.applymap(lambda x: ord_dict.get(x,x))
    return df

# %%
df = ordinal_mapper(df, ordinal_features)

# %%
# Now dummify the nominal columns
df = pd.get_dummies(df, columns=categorical_features, drop_first=True, dummy_na=True)

# %%
# Save this version of the data as well
df.to_csv('../datasets/cleaned-data.csv',index=False)

# %% [markdown]
# With the data cleaned and saved, we can move onto the modeling portion, which can be found in [this notebook](02-modeling.ipynb). Also, if you would like to get a more condensed version of this cleaning code, you can find it [here.](cleaner.py)
